// %%
:dep plotters = { version = "^0.3.5", default_features = false, features = ["evcxr", "all_series"] }

// %%
extern crate plotters;
use plotters::prelude::*;

// %%
evcxr_figure((640,480),|root|{
    &root.fill(&WHITE)?;
    let mut chart = ChartBuilder::on(&root)
        .caption("y = x^2 - x + 6", ("sans-serif", 40.0))
        .x_label_area_size(35)
        .y_label_area_size(40)
        .build_cartesian_2d(-5.5..5.5, 5.0..40.0)?;

chart
    .configure_mesh()
    .x_labels(11)
    .y_labels(5)
    .draw()?;

chart.draw_series(LineSeries::new(
    (-50..=50).map(|x| x as f64 / 10.0).map(|x| (x, x * x - x + 6.0)),
    &BLUE,
))?; 
Ok(())
})
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="5" dy="0.76em" text-anchor="middle" font-family="sans-serif" font-size="32.25806451612903" opacity="1" fill="#000000">
// y = x^2 - x + 6
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="45" y1="444" x2="45" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="56" y1="444" x2="56" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="67" y1="444" x2="67" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="78" y1="444" x2="78" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="89" y1="444" x2="89" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="99" y1="444" x2="99" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="110" y1="444" x2="110" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="121" y1="444" x2="121" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="132" y1="444" x2="132" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="143" y1="444" x2="143" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="154" y1="444" x2="154" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="165" y1="444" x2="165" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="176" y1="444" x2="176" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="187" y1="444" x2="187" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="197" y1="444" x2="197" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="208" y1="444" x2="208" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="219" y1="444" x2="219" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="230" y1="444" x2="230" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="241" y1="444" x2="241" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="252" y1="444" x2="252" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="263" y1="444" x2="263" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="274" y1="444" x2="274" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="285" y1="444" x2="285" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="295" y1="444" x2="295" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="306" y1="444" x2="306" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="317" y1="444" x2="317" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="328" y1="444" x2="328" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="339" y1="444" x2="339" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="350" y1="444" x2="350" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="361" y1="444" x2="361" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="372" y1="444" x2="372" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="383" y1="444" x2="383" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="393" y1="444" x2="393" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="404" y1="444" x2="404" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="415" y1="444" x2="415" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="426" y1="444" x2="426" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="437" y1="444" x2="437" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="448" y1="444" x2="448" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="459" y1="444" x2="459" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="470" y1="444" x2="470" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="481" y1="444" x2="481" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="491" y1="444" x2="491" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="502" y1="444" x2="502" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="513" y1="444" x2="513" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="524" y1="444" x2="524" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="535" y1="444" x2="535" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="546" y1="444" x2="546" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="557" y1="444" x2="557" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="568" y1="444" x2="568" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="579" y1="444" x2="579" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="589" y1="444" x2="589" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="600" y1="444" x2="600" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="611" y1="444" x2="611" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="622" y1="444" x2="622" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="633" y1="444" x2="633" y2="42"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="444" x2="639" y2="444"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="433" x2="639" y2="433"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="422" x2="639" y2="422"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="410" x2="639" y2="410"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="399" x2="639" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="387" x2="639" y2="387"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="376" x2="639" y2="376"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="364" x2="639" y2="364"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="353" x2="639" y2="353"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="341" x2="639" y2="341"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="330" x2="639" y2="330"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="318" x2="639" y2="318"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="307" x2="639" y2="307"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="295" x2="639" y2="295"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="284" x2="639" y2="284"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="272" x2="639" y2="272"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="261" x2="639" y2="261"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="249" x2="639" y2="249"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="238" x2="639" y2="238"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="226" x2="639" y2="226"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="215" x2="639" y2="215"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="203" x2="639" y2="203"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="192" x2="639" y2="192"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="180" x2="639" y2="180"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="169" x2="639" y2="169"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="157" x2="639" y2="157"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="146" x2="639" y2="146"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="134" x2="639" y2="134"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="123" x2="639" y2="123"/>
// <line opacity="0.1"
